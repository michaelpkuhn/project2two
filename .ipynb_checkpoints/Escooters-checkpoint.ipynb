# %%
# Dependencies
import requests
import json 
import csv 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import requests
import time

# %%
# URL for GET requests to retrieve vehicle data
url = "https://data.cityofchicago.org/resource/2kfw-zvte.json"

# %%
# Print the response object to the console
print(requests.get(url))
# Out:
# <Response [200]>

# %%
# Pretty Print the output of the JSON
response = requests.get(url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# [
#     {
#         ":@computed_region_bdys_3d7i": "126",
#         ":@computed_region_vrxf_vc4k": "33",
#         "accuracy": "152",
#         "end_centroid_latitude": "41.8502661710639",
#         "end_centroid_location": {
#             "coordinates": [
#                 -87.6675682255936,
#                 41.8502661710639
#             ],
#             "type": "Point"
#         },
#         "end_centroid_longitude": "-87.6675682255936",
#         "end_community_area_name": "LOWER WEST SIDE",
#         "end_community_area_number": "31",
#         "end_time": "2019-06-15T05:00:00.000",
#         "start_centroid_latitude": "41.8502661710639",
#         "start_centroid_location": {
#             "coordinates": [
#                 -87.6675682255936,
#                 41.8502661710639
#             ],
#             "type": "Point"
#         },
#         "start_centroid_longitude": "-87.6675682255936",
#         "start_community_area_name": "LOWER WEST SIDE",
# ...

# %%
# Pretty print JSON for a specific parameter
#response = requests.get(url + "parameter").json()
#print(json.dumps(response, indent=4, sort_keys=True))

# %%
scooters_df = pd.read_csv('EScooter_Trips_Small.csv')

scooters_df.head()
# Out:
# /Users/aribuenrostro/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (8,9,12,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                 Trip ID     Start Time       End Time  \
# 0  758e9d21-609f-5479-8e2c-5e8f64258202   7/1/19 17:00   7/1/19 17:00
# 1  ff33490c-254a-5af2-9315-d6b2a45b07f7  6/29/19 18:00  6/29/19 18:00
# 2  f8a25729-e853-40f3-9200-7eea9f9c45f2  9/16/19 13:00  9/16/19 13:00
# 3  11d42b99-e839-346c-11d4-2b99e839346c  6/24/19 19:00  6/24/19 19:00
# 4  0c226130-0fa6-518f-8fe6-219b9fa5f42f  7/12/19 19:00  7/12/19 19:00
#
#    Trip Distance  Trip Duration  Accuracy  Start Community Area Number  \
# 0            421              3         1                          NaN
# 1           6318             31         1                          NaN
# ...

# %%
scooters_df.describe()
# Out:
#        Trip Distance  Trip Duration      Accuracy  \
# count   7.108390e+05  710839.000000  7.108390e+05
# mean    1.197720e+04     722.229930  7.646578e+02
# std     6.177556e+05    1312.577602  1.093487e+05
# min     0.000000e+00   -1642.000000  0.000000e+00
# 25%     6.120000e+02     189.000000  1.000000e+00
# 50%     1.366000e+03     407.000000  1.000000e+01
# 75%     2.773000e+03     829.000000  1.520000e+02
# max     2.156535e+08  110628.000000  6.033700e+07
#
#        Start Community Area Number  End Community Area Number  \
# count                613450.000000              612923.000000
# mean                     24.748105                  24.598132
# std                       3.281728                   3.530747
# min                       3.000000                   2.000000
# 25%                      22.000000                  22.000000
# 50%                      24.000000                  24.000000
# 75%                      28.000000                  28.000000
# ...

# %%
#Temperature vs Latitude scatterplot
x_axis = scooters_df['Trip Distance']
y_axis = scooters_df['Trip Duration']
plt.scatter(x_axis, y_axis)
plt.title("Trip Duration vs Trip Distance")
plt.xlabel("Trip Duration (secs)")
plt.ylabel("Trip Distance (meters)")
plt.tick_params(axis='both', which='major', labelsize=14)
plt.axis()
plt.grid()
plt.savefig('E-Scooter Trip Duration vs Trip Distance.png')

plt.show()
